# %% [markdown]
# <a href="https://colab.research.google.com/github/JogGiri/python/blob/main/Request.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
response = requests.get("https://www.codewithharry.com/")

# %%
print(response.text)
# Out:
# <!DOCTYPE html><html><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><link rel="shortcut icon" href="/img/favicon.ico" type="image/x-icon"/><script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9655830461045889" crossorigin="anonymous"></script><title>Learn to code online - CodeWithHarry</title><meta name="description" content="Generated by create next app"/><link rel="icon" href="/img/favicon.ico"/><meta name="next-head-count" content="7"/><meta name="next-font-preconnect"/><link rel="preload" href="/_next/static/css/ced2f5f753e05303.css" as="style"/><link rel="stylesheet" href="/_next/static/css/ced2f5f753e05303.css" data-n-g=""/><link rel="preload" href="/_next/static/css/470c5e8db7cdc7e9.css" as="style"/><link rel="stylesheet" href="/_next/static/css/470c5e8db7cdc7e9.css" data-n-p=""/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-5cd94c89d3acac5f.js"
# ...

# %%
with open('index.html','w') as f:
  f.write(response.text)

# %%
r = requests.get('https://api.github.com/events')
print(r.status_code)

print(r.headers['content-type'])

print(r.encoding)

print(r.text)

print(r.json())
# Out:
# 200
# application/json; charset=utf-8
# utf-8
# ...

# %%
r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '28308693548',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 105929,
#    'login': 'fujiwarat',
#    'display_login': 'fujiwarat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fujiwarat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105929?'},
#   'repo': {'id': 895564,
#    'name': 'ibus/ibus',
#    'url': 'https://api.github.com/repos/ibus/ibus'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/ibus/ibus/issues/2501',
#     'repository_url': 'https://api.github.com/repos/ibus/ibus',
#     'labels_url': 'https://api.github.com/repos/ibus/ibus/issues/2501/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ibus/ibus/issues/2501/comments',
#     'events_url': 'https://api.github.com/repos/ibus/ibus/issues/2501/events',
#     'html_url': 'https://github.com/ibus/ibus/issues/2501',
#     'id': 1659673154,
#     'node_id': 'I_kwDOAA2qTM5i7JpC',
#     'number': 2501,
# ...
